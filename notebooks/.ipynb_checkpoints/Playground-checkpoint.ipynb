# %% [markdown]
# # Playground

# %%
print ("Esto es una prueba :D")
# Out:
# Esto es una prueba :D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s.describe()
# Out:
# count    5.000000
# mean     4.600000
# std      2.701851
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      6.000000
# max      8.000000
# dtype: float64

# %%
a = pd.DataFrame([1, 1, 1, np.nan], index=['a', 'b', 'c', 'd'], columns=['one'])
a
# Out:
#    one
# a  1.0
# b  1.0
# c  1.0
# d  NaN

# %%
b = pd.DataFrame(dict(one=[1, np.nan, 1, np.nan], two=[np.nan, 2, np.nan, 2]), index=['a', 'b', 'd', 'e'])
b
# Out:
#    one  two
# a  1.0  NaN
# b  NaN  2.0
# d  1.0  NaN
# e  NaN  2.0

# %%
a.add(b, fill_value=0)
# Out:
#    one  two
# a  2.0  NaN
# b  1.0  2.0
# c  1.0  NaN
# d  1.0  NaN
# e  NaN  2.0

# %%
dates = pd.date_range('20130101', periods=6)
dates
#df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.083415  1.280635  1.027166 -0.768358
# 2013-01-02 -0.302402 -1.026940  0.329405  0.286726
# 2013-01-03 -0.065937  0.409213  0.130165  0.012035
# 2013-01-04 -0.047211  1.054826 -0.219593  0.833260
# 2013-01-05 -0.364808  0.653027  0.206318  0.333267
# 2013-01-06 -0.247618  0.356434 -1.711154 -0.006935

# %%
df2 = pd.DataFrame({ 
   'A' : 1.,
   'B' : pd.Timestamp('20130102'),
   'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
   'D' : np.array([3] * 4,dtype='int32'),
   'E' : pd.Categorical(["test","train","test","train"]),
   'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
ejemplo = pd.DataFrame({'AAA' : [4,5,6,7], 'BBB' : [10,20,30,40],'CCC' : [100,50,-30,-50]})
ejemplo
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
exam_data  = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df_estudiantes = pd.DataFrame(exam_data , index=labels)
df_estudiantes
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
color = ['Red','Blue','Orange','Red','White','White','Blue','Green','Green','Red']
df_estudiantes['color'] = color
df_estudiantes
# Out:
#         name  score  attempts qualify   color
# a  Anastasia   12.5         1     yes     Red
# b       Dima    9.0         3      no    Blue
# c  Katherine   16.5         2     yes  Orange
# d      James    NaN         3      no     Red
# e      Emily    9.0         2      no   White
# f    Michael   20.0         3     yes   White
# g    Matthew   14.5         1     yes    Blue
# h      Laura    NaN         1      no   Green
# i      Kevin    8.0         2      no   Green
# j      Jonas   19.0         1     yes     Red
